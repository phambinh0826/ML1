# %% [markdown]
# # Lecture 1 - Graph Theory and Centrality Measures

# %% [markdown]
# ## Thuật ngữ

# %% [markdown]
# **Một đồ thị (graph)** là một tập hợp các điểm, thường được gọi là đỉnh (vertices) hoặc nút (nodes), được kết nối với nhau bởi các đoạn thẳng gọi là cạnh (edges) hoặc liên kết (links).
#
# **Mạng xã hội (social networks)** là các đồ thị chứa một tập hợp hữu hạn hoặc các tập hợp các tác nhân (agents) mà chúng ta gọi là các đối tượng (actors), và các quan hệ (relations) được định nghĩa giữa chúng. Hình dưới đây có bốn đỉnh.
#
# ![fig1](fig1.png)

# %% [markdown]
# Khi di chuyển từ một đỉnh này sang đỉnh khác dọc theo một cạnh duy nhất nối chúng lại với nhau được gọi là một bước (step). Một đường đi (walk) là một chuỗi các bước từ một đỉnh này đến đỉnh khác; số bước chính là độ dài (length) của đường đi. Ví dụ, có một đường đi ba bước từ đỉnh 1 đến đỉnh 3 sử dụng các bước từ 1 đến 4, từ 4 đến 2, và từ 2 đến 3.
#
# **Một dấu vết (trail):**
# - Trail là một chuỗi các liên kết (links) nối với nhau trong một đồ thị, trong đó mỗi liên kết chỉ xuất hiện một lần, nhưng các nút (nodes) có thể xuất hiện nhiều lần. Nói cách khác, trong dấu vết, mỗi liên kết có thể được đi qua một lần duy nhất, nhưng các nút (ví dụ: các điểm giao tiếp trong mạng xã hội) có thể được lặp lại. Độ dài của dấu vết là số liên kết trong đó.
#
# > Ví dụ:
# > - Trong một mạng xã hội, nếu bạn theo dõi một người nào đó và từ đó bạn tiếp tục theo dõi những người mà người đó đang theo dõi, bạn có thể quay lại một số nút (người) trong mạng, nhưng mỗi đường nối giữa các người (liên kết) chỉ đi qua một lần.
#
# **Một con đường (path):**
# - Path là một đường đi trong đó tất cả các nút và liên kết đều khác biệt. Điều này có nghĩa là không được phép lặp lại cả các nút và các liên kết trong suốt hành trình. Mỗi nút và mỗi liên kết đều được sử dụng một lần duy nhất trong con đường.
#
# > Ví dụ:
# > - Trong mạng xã hội, một con đường sẽ đại diện cho một chuỗi người bạn mà bạn có thể đi qua mà không quay lại ai đó đã gặp trước đó, và mỗi người bạn chỉ được kết nối một lần.
#
# **Mối quan hệ giữa dấu vết và con đường:**
# - Lưu ý rằng mỗi con đường đều là một dấu vết. Tuy nhiên, không phải dấu vết nào cũng là một con đường, vì dấu vết có thể có các nút lặp lại, trong khi con đường thì không.
# - Tóm lại, mọi Path đều là Trail, mỗi Trail là một cuộc đi bộ và mỗi lần đi bộ đều bao gồm 1 số bước (step).
#
# Trong ứng dụng mạng xã hội, việc tìm kiếm con đường quan trọng hơn vì nó giúp hiểu rõ hơn về mối quan hệ trực tiếp giữa các người dùng mà không có sự lặp lại nào.

# %% [markdown]
# Một thuộc tính rất quan trọng của một cặp nút là liệu có tồn tại một con đường giữa chúng hay không. Nếu có một con đường giữa, ví dụ, nút 1 và nút 2, thì các nút này được gọi là có thể tiếp cận **(reachable)**. Một đường đi bắt đầu và kết thúc với cùng một nút được gọi là một đường đi kín **(closed walk)**. Một chu trình **(cycle)** là một đường đi kín có ít nhất ba nút. Các chu trình rất quan trọng trong việc nghiên cứu sự cân bằng và khả năng phân cụm trong đồ thị có dấu **(signed graphs)** (một chủ đề mà chúng ta sẽ khám phá trong bài học 3).

# %% [markdown]
# ### **Ma trận Kề (Adjacency Matrix), Đồ thị và Ký hiệu**
# Mạng xã hội có thể được biểu diễn dưới dạng đồ thị hoặc ma trận. Ví dụ, đây là một đồ thị biểu diễn mối quan hệ tình bạn giữa một nhóm người:
#
# ![fig2](fig2.png)
#
# Chúng ta cũng có thể ghi lại cách các thực thể liên kết với nhau trong một ma trận kề.
#
# Ma trận kề trong trường hợp này là một ma trận vuông (có nghĩa là số hàng bằng số cột và đều tương ứng với các nút) theo dạng tác nhân (agent) với các tác nhân.
#
# ![fig3](fig3.png)
#
# > **1** là nếu có cạnh giữa 2 nút <br>
# > **0** là nếu không có cạnh giữa 2 nút
#
# Về mặt toán học, bất kỳ mạng lưới nào cũng có thể được biểu diễn bằng ma trận kề, trường hợp dưới đây là đơn giản nhất: **mạng lưới nhị phân.**
#
# $$
# a_{ij} =
# \begin{cases}
# 1 & \text{nếu có một cạnh giữa } n_i \text{ và } n_j \\
# 0 & \text{nếu không có cạnh giữa } n_i \text{ và } n_j
# \end{cases}
# $$

# %% [markdown]
# **MỘT SỐ KÝ HIỆU KHÁC**
#
# | Ký hiệu | Ý nghĩa |
# |---------|---------|
# | $$\sum_i x_i$$ | Tổng các giá trị của "x", ví dụ như $x_1 + x_2 + \cdots + x_N$ |
# | $A$ | Ma trận kề, ví dụ như $A = \begin{bmatrix} a_{ij} & \cdots & a_{iN} \\ \vdots & \ddots & \vdots \\ a_{Nj} & \cdots & a_{NN} \end{bmatrix}$ trong đó liên kết $a_{ij}$ là giữa tác nhân $i$ và tác nhân $j$. |
# | $A^T$ | Chuyển vị của ma trận kề, ví dụ như $A^T = \begin{bmatrix} a_{ij} & \cdots & a_{Nj} \\ \vdots & \ddots & \vdots \\ a_{iN} & \cdots & a_{NN} \end{bmatrix}$ trong đó liên kết $a_{ij}$ là giữa tác nhân $i$ và tác nhân $j$. |

# %% [markdown]
# Hóa ra, ma trận kề $A$ cho Hình 2 là chìa khóa để giải quyết vấn đề. Bằng cách thực hiện nhiều phép hợp thành của ma trận kề, $A^n$ cho biết số lượng các đường đi có độ dài $n$ giữa tất cả các nút trong mạng lưới.
#
# Vì vậy, Will Hunting đã sử dụng khoa học mạng trong hai bước đầu tiên của giải pháp bốn bước của anh ấy. Chúng ta sẽ học cách thực hiện phép tính này sau. Thật thú vị!

# %% [markdown]
# ### **Types of Networks**
# ![fig4](fig4.png)
#
# Bây giờ, có rất nhiều loại mạng khác nhau, và điều này chỉ giúp bạn thấy một phần về các loại cấu trúc mạng khác nhau. Bạn có thể học được rất nhiều về những gì xảy ra trong các mạng xã hội của một tổ chức vì có rất nhiều yếu tố ảnh hưởng từ tâm lý xã hội, tâm lý nhận thức, và cách con người hành động trong nhóm sẽ hình thành cấu trúc mạng lưới của họ. Điều này cũng có thể ảnh hưởng đến những gì bạn đang đo lường hoặc quan sát. Tôi muốn giới thiệu một số loại mạng phổ biến mà chúng tôi hay đề cập.
#
# 1. **Mạng lõi-ngoại vi (core-periphery network):** Được định nghĩa là có một lõi nhỏ ở trung tâm, tất cả các nút trong lõi này đều kết nối với nhau. Sau đó, có rất nhiều nút kết nối với một trong các nhóm lõi, nhưng không nhất thiết phải kết nối với nhau. Mạng lõi-ngoại vi thường thấy trong các tổ chức tình nguyện hoặc các nhóm tôn giáo, nơi một nhóm nhỏ tham gia và một số người tham gia khác không được kết nối tốt như những người trong nhóm lõi.
#
# 2. **Mạng tế bào (cellular networks):** Có một nhóm lõi, nhưng có các tế bào được kết nối tại các điểm này. Mạng tế bào có thể là một mô hình lý thuyết nhiều hơn so với thực tế, vì các tổ chức bí mật hoặc các nhóm phiến quân không sử dụng nó hiệu quả. Trong cuộc chiến toàn cầu chống khủng bố, quân đội Mỹ đã rất giỏi trong việc tìm kiếm và nhắm mục tiêu các mạng tế bào, dẫn đến sự suy giảm trong việc sử dụng chúng.
#
# 3. **Mạng lưới lưới (Lattice network):** Trong mạng lưới này, mỗi người đều kết nối với đúng số lượng người khác, nhưng các kết nối này là khác nhau. Đây là một mô hình lý thuyết cực đoan và không phản ánh thực tế vì mọi người có sự khác biệt trong sở thích và kết nối của mình.
#
# 4. **Đồ thị Erdos-Renyi:** Mỗi người kết nối với một người khác với xác suất P và xác suất gặp tất cả những người khác là như nhau, dẫn đến một đồ thị ngẫu nhiên. Nếu thay đổi sở thích của mọi người, dần dần bạn sẽ tạo ra một đồ thị Erdos-Renyi.
#
# 5. **Mạng không tỉ lệ (Scale-Free network):** Khi một người gia nhập mạng và chọn kết nối với những nút phổ biến hơn với xác suất lớn hơn, các hub sẽ hình thành. Đây là các nút trung tâm có rất nhiều kết nối, trong khi hầu hết mọi người chỉ có ít kết nối. Các mạng này không tỉ lệ và thường thấy trong các mạng xã hội, chẳng hạn như những người nổi tiếng có rất nhiều người theo dõi, còn phần lớn chúng ta có rất ít người theo dõi.
#
# Thực tế là các mạng không tỉ lệ này cũng có thể được thiết kế thông qua các yếu tố như tối ưu hóa trong ngành hàng không, với các nút trung tâm để điều hướng hiệu quả.
#
# Những kiểu mẫu mạng này giúp chúng ta hiểu về các ngữ cảnh cực đoan và cũng cho chúng ta cái nhìn sâu sắc về những gì đang xảy ra với các mạng xã hội thực tế mà chúng ta nghiên cứu.

# %% [markdown]
# ### **So sánh giữa phân tích truyền thống và phân tích mạng xã hội**
#
# |  | **Truyền thống** | **Mạng lưới** |
# |----------------------------|------------------|---------------|
# | **Tiêu điểm phân tích dữ liệu** | Cá nhân, Tác nhân/Thực thể | Dyad, Triad |
# | **Loại dữ liệu** | Thuộc tính | Quan hệ |
# | **Giả thuyết về dữ liệu** | Độc lập | Phụ thuộc |
# | **Môi trường thí nghiệm** | Kiểm soát | Phức tạp |
# | **Nhận thức** | Các yếu tố quan trọng | Các tương tác |
# | **Khung phân tích** | Tương quan | Cấu trúc |
# | **Nền tảng toán học** | Giải tích | Lý thuyết đồ thị, Đại số tuyến tính, Toán học rời rạc |

# %% [markdown]
# Có một loại so sánh khác mà tôi muốn chỉ ra giữa phân tích truyền thống và phân tích mạng lưới. Vì vậy, tôi chỉ muốn làm nổi bật một số điểm chính ở đây. Mục tiêu của phân tích là khác nhau. Khi chúng ta làm việc với phân tích truyền thống, chúng ta thường nghĩ mọi thứ là độc lập và phân phối đồng nhất. Chúng ta nghĩ về các cá nhân.
#
# > Chúng ta nghĩ về việc nếu bạn đến văn phòng bác sĩ và một đứa trẻ bị viêm họng do liên cầu, chúng ta sẽ nghĩ về đứa trẻ đó. Chúng ta sẽ kê đơn Amoxicillin. Sau đó, nếu nó không phản ứng với Amoxicillin vì có một tác nhân bệnh khác, chúng ta sẽ quay lại và cho Menton.
# >
# > Nhưng rồi một đứa trẻ khác đến với các triệu chứng tương tự. Một lần nữa, chúng ta sẽ điều trị chúng độc lập, chúng ta sẽ cho chúng Amoxicillin và đó là phác đồ y tế điển hình.
# >
# > Tại sao chúng ta không bắt đầu với Augmentin? Nếu chúng ta áp dụng phân tích mạng lưới, chúng ta sẽ nhận ra rằng bệnh nhân tiếp theo có thể đã tiếp xúc với người bệnh trước đó phải quay lại vì Augmentin, và chúng ta có thể bắt đầu với Augmentin. Augmentin chỉ là Amoxicillin với một loại thuốc bổ sung. Và chúng ta không muốn cho người bệnh dùng Augmentin ngay lập tức vì chúng ta không muốn làm tăng khả năng miễn dịch của họ đối với phần bổ sung. Nhưng nếu chúng ta biết họ có khả năng tiếp xúc với tác nhân bệnh đó, và chúng ta không. Chúng ta bắt đầu với Amoxicillin. Chúng ta đã cho họ hai đợt điều trị Amoxicillin, và đã làm cho họ kháng lại loại kháng sinh phổ biến hơn và được sử dụng rộng rãi hơn.
#
# Vì vậy, cách chúng ta nhìn vào các cá nhân so với các cặp (diads) và bộ ba (triads), như diads nghĩa là hai, triads nghĩa là ba, những mối quan hệ này có những tác động quan trọng trong cách chúng ta giải quyết vấn đề.
#
# Loại dữ liệu mà chúng ta xem xét trong phân tích truyền thống là các thuộc tính.
#
# > Tôi có thể nói gì về người đó? Tôi có thể nói gì về tuổi tác, gen và điểm IQ của họ, và tất cả các thuộc tính mà tôi có thể nói về một người. Điều này có phải là yếu tố góp phần vào béo phì không?
#
# Network Analysis thì sẽ là
#
# > Họ kết nối với ai? Cân nặng và BMI của những người có mối quan hệ với họ là gì?
# >
# > Và những gì chúng ta phát hiện khi đi vào khía cạnh mối quan hệ là những điều thú vị, như bạn có biết béo phì là có thể lây lan xã hội không?
# >
# > Khi mọi người có mối quan hệ với những người có khối lượng cơ thể lớn hơn, họ có xu hướng có những ý tưởng mới về khối lượng cơ thể chấp nhận được và họ có xu hướng trở nên lây lan trong xã hội.
# >
# > Điều này không xảy ra theo chiều ngược lại, nơi gầy gò là có thể lây lan xã hội, nhưng có một số sinh lý thần kinh ảnh hưởng đến điều đó.
#
# Có rất nhiều điều quan trọng từ góc độ Network Analysis. Như tôi đã đề cập, chúng ta giả định trong phân tích truyền thống rằng mọi người đều độc lập với những người xung quanh họ.
#
# > Trong mạng lưới, chúng ta giả định mức độ phụ thuộc cao. Khi chúng ta thực hiện thí nghiệm, chúng ta kiểm soát các biến và yếu tố khác nhau trong một môi trường thí nghiệm, để có thể có nhóm kiểm soát, nhóm thử nghiệm và kiểm tra sự khác biệt.
#
# > Nhưng trong mạng lưới, chúng ta nhận ra rằng điều đó không hoạt động, vì vậy chúng ta phải thiết kế các thí nghiệm phức tạp hơn ngoài những gì đã trình bày trong phần này.
#
# > Trong phân tích truyền thống, chúng ta nhìn vào mối quan hệ (correlation) như là một khung phân tích.
#
# > Trong mạng lưới, chúng ta nhìn vào cấu trúc của mạng lưới. Chúng ta nhìn vào, ví dụ, liệu nó có được phân nhóm không? Nó có phải là một khối lớn không? Tất cả những điều này giúp chúng ta nhận thức về vấn đề mà chúng ta đang nghiên cứu và bản chất của dữ liệu.
#
# Nền tảng toán học là rất khác biệt. Vì vậy, trong phân tích truyền thống, nó dựa trên Giải tích (Calculus), ngay cả khi là thống kê, thống kê cũng dựa trên Giải tích. Nhưng trong phân tích mạng lưới, chúng ta dựa vào lý thuyết đồ thị, đại số tuyến tính và toán học rời rạc.
#
# Bây giờ, bạn có thể đã quen với những điều này vì chúng ta đang học trong một chương trình khoa học máy tính. Những người trong ngành này có xu hướng sử dụng chúng nhiều hơn, và điều đó rất tuyệt. Hầu hết mọi người ở Mỹ đều đã có một chút tiếp xúc với Giải tích qua trung học và đại học, vì vậy họ quen thuộc hơn với nó. Nó dễ tiếp cận hơn. Nhưng khi nghĩ về các mạng lưới và các loại toán học khác so với những gì họ đã quen, tôi sẽ tranh luận rằng toán học này không khó hơn. Thực tế là nó có thể dễ hơn Giải tích 2, nhưng nó khác biệt và sự khác biệt đó khiến chúng ta ra khỏi vùng thoải mái của mình và làm cho mọi thứ trở nên không thoải mái hơn.

# %% [markdown]
# ## Degree Centrality

# %% [markdown]
# Đây có lẽ là chỉ số mạng xã hội đơn giản nhất để tính toán, và nó được sử dụng phổ biến trong nhiều ứng dụng.
#
# ### **Mục tiêu**
# - Phân biệt giữa bốn chỉ số trung tâm cơ bản mà chúng ta sẽ nói đến
# - Cách tính toán độ trung tâm theo bậc bằng tay như thế nào?
#
#
# ### **Tính trung tâm là gì và tại sao chúng ta nghiên cứu nó?**
# Khi tôi trình bày mạng này, bạn nghĩ ai là người quan trọng nhất?
#
# ![Hình 5](fig5.png)
#
# Tôi muốn bạn tạm dừng, nhìn vào nó một lúc và ghi lại cho mình những nút quan trọng nhất mà bạn nghĩ sẽ có tầm ảnh hưởng nhất.
#
# Bạn có thể nhận ra mạng này là mạng lõi-ngoại vi (core-periphery network). Nó có một số tác nhân trung tâm, tôi tin rằng các tác nhân 2, 8, 5, 17, 18 và 39 là lõi, và sau đó tất cả các tác nhân khác đều kết nối với một trong các nhóm lõi đó.
#
# Nhưng khi chúng ta nhìn vào ai là người quan trọng nhất, thì có một chút khó khăn. Nếu tôi nhìn vào một mạng có hình dạng không quá rõ ràng, có vẻ khó để đưa ra quyết định. Bạn có thể tạm dừng và thử lại bài tập này.
#
# Bạn nghĩ ai là người quan trọng nhất? Giả sử bạn đã có cơ hội làm điều đó, điều gì sẽ xảy ra nếu không có câu trả lời đúng trong trường hợp này? Thực tế là rất khó để đưa ra câu trả lời trong bối cảnh sau.
#
# ![Hình 6](fig6.png)
#
# Những gì chúng ta sẽ làm với các chỉ số trung tâm là tìm ra những cách khác nhau để đo lường ai là người trung tâm hay ai là người quan trọng trong mạng lưới. Điều này tương tự như khái niệm trung bình, trung vị, mode với dữ liệu truyền thống.
#
# **Các phép đo trung tâm (Measures of Center)**
#
# - **Trung bình (Mean - Average)**:
#   $$ \frac{\sum x_i}{n} $$
#   (Tổng của tất cả các giá trị $x_i$ chia cho số lượng $n$)
#
# - **Trung vị (Median)**:
#   Sắp xếp danh sách và sau đó xác định giá trị nằm ở giữa danh sách.
#
# - **Mode (Mode)**:
#   Giá trị dữ liệu có tần suất cao nhất.
#
# Tôi sẽ chỉ cho bạn sự tương đồng này với mạng lưới ngay sau đây.
#
# ### **Bài tập thực hành**
# Tôi muốn bạn tạm dừng và dành một chút thời gian suy nghĩ về 10 số có trung bình là 6, trung vị là 5 và mode là 4.
#
# Điều này sẽ quan trọng khi bạn suy nghĩ về sự kết nối giữa những gì chúng ta biết về các số phân phối đồng nhất và không đồng nhất, nơi chúng ta tính toán trung bình, trung vị, mode cho lý thuyết đồ thị, nơi chúng ta sẽ áp dụng sự gần gũi và độ trung tâm. Hãy dành một chút thời gian và làm bài trên nhé.
#
# > Không có câu trả lời đúng trong bài toán này.
# >
# > Cách tôi giải quyết bài toán này là tôi biết rằng tôi có 10 số sẽ cộng lại thành 60.
# >
# > Sau đó tôi sẽ nghĩ rằng tôi cần có mode là 4, nên tôi phải có ít nhất hai số là 4. Tôi có 4 và 4.
# >
# > Sau đó tôi biết để có trung vị là 5, thì số thứ 5 và thứ 6 phải là 5. Điều đó có nghĩa là tôi có 5, 5, 4, 4.
# >
# > Sau đó tôi phải có thêm một số thấp hơn cái đó. Tôi sẽ cần thêm hai số thấp hơn nữa, vì vậy tôi có thể thêm một số 4 nữa hoặc có thể tôi chỉ thêm tất cả số 4, không sao.
# >
# > Sau đó tôi có thể tạo các số còn lại tùy ý, miễn là không vượt quá tổng 60.
#
# Đây là mô tả sơ lược, nhưng nó cho bạn hướng đi về cách bạn có thể tạo ra một trung bình là 6, trung vị là 5 và mode là 4. Tuy nhiên, phần quan trọng là tất cả các phép đo này, mặc dù tính toán khác nhau và khác nhau trên một tập hợp 10 số, đều là các phép đo trung tâm.
#
# Chúng là các phép đo cố gắng xác định trung tâm. Chúng ta biết rằng khi chúng ta có một phân phối đối xứng, có một đường cong chuông, có số lượng lớn bằng nhau giữa các giá trị cao và thấp, thì trung bình hoạt động rất tốt và chúng ta thường xuyên sử dụng trung bình.
#
# Tại sao chúng ta sử dụng trung bình nhiều vậy? Chúng ta sử dụng trung bình vì có lẽ nó dễ tính toán hơn trung vị, nhiều khi vì bạn không phải sắp xếp dữ liệu. Nhưng vấn đề khác với trung bình là có một định lý gọi là **định lý giới hạn trung tâm** trong thống kê, đó là nếu tôi lấy trung bình của 30 số trở lên, tôi sẽ biết phân phối của trung bình đó. Ngay cả khi các số có phân phối rất lệch, nếu tôi đang lấy mẫu và lấy trung bình của chúng, tôi biết phân phối, điều này cho phép tôi có suy luận thống kê về việc so sánh hai nhóm hoặc sự thay đổi. Chúng ta thường sử dụng trung bình vì chúng ta có thể sử dụng các tính chất khác mà chúng ta không dành thời gian để dạy mọi người.
#
# Nhưng khi bạn có dữ liệu bị lệch rất nhiều, điều này được sử dụng nhiều trong kinh tế học hoặc chính trị vì có rất nhiều người giàu và nghèo, và khi bạn có một quần thể lệch như vậy, nếu chúng ta lấy giá trị trung bình, chúng ta sẽ suy luận hoặc ước đoán về một cái gì đó không thực sự đại diện cho bất kỳ nhóm nào.Chúng ta sử dụng trung vị như một cách hiệu quả hơn để đo lường trung tâm khi có cấu trúc cao hoặc sự lệch trong dữ liệu.
#
# Mode không được sử dụng nhiều, mặc dù có thể là cách dễ nhất để đo lường. Tương tự, chúng ta có thể nhìn vào mạng lưới kiểu mẫu này từ Dave Crackhart.
#
# ![Hình 7](fig7.png)

# %% [markdown]
# Bây giờ, mạng lưới, chỉ để cung cấp cho bạn một số thông tin nền, là một trong những sinh viên của Dave Crackhart, Red, và ở dưới đây.
#
# Red không phải là tôi. Tôi biết tôi có tóc đỏ, nhưng không phải là tôi. Anh ta là một sinh viên quân sự trong lớp của Dave Crackhart, và bài tập của anh ấy sau khi tốt nghiệp là tại Lầu Năm Góc. Có một mạng lưới này, và Sam, ở góc trên bên phải gần với 'Degree', là tướng một sao người đã phụ trách nhóm này tại Lầu Năm Góc và hai nhóm khác nhau đã được hợp nhất lại.
#
# Sam đã phụ trách, vì vậy Red nghĩ anh ấy sẽ chỉ cho nhóm phân tích mạng xã hội. Cuối cùng điều đó không phải là một ý tưởng hay. Nhưng chúng ta có được những mạng lưới kiểu mẫu tuyệt vời từ bài tập này với Dave.
#
# Những gì chúng ta thấy ở đây là một mạng lưới có cấu trúc, vì vậy có một nhóm ở góc trên bên phải và một nhóm ở góc dưới bên trái, và bạn thấy *"Conrad"* ở giữa. Khi chúng ta nhìn vào các thuật ngữ **degree, betweeness, closeness, eigenvector,** chúng là những cách khác nhau để đo lường trung tâm.
#
# > 1. Khi tôi nhìn vào **degree**, tôi thấy Linda có nhiều kết nối vật lý nhất trong mạng lưới. Cô ấy kết nối với nhiều người hơn bất kỳ ai khác. Tôi nghĩ Roger đứng thứ hai, nhưng Linda có nhiều kết nối hơn bất kỳ ai khác. Nhưng Linda là trung tâm trong nhóm ở góc trên bên phải và cô ấy không gần với những người trong nhóm dưới bên trái.
# >
# > 2. Nếu bạn nhìn vào Roger, Roger gần hơn với tất cả mọi người khác trung bình. Nếu chúng ta đo chiều dài của các đường đi ngắn nhất giữa tất cả các cặp nút và sau đó tính trung bình, chúng ta sẽ thấy rằng Roger có khoảng cách ngắn nhất trung bình đến tất cả mọi người khác trong mạng lưới. Đó là một loại trung tâm khác - **closeness**.
# >
# > 3. Sau đó, người nổi bật với mọi người là Conrad vì Conrad là một cầu nối đơn lẻ giữa hai nhóm, và anh ấy có mức độ **betweeness** cao. Nếu bạn nhìn vào đường đi ngắn nhất và nói, tần suất các nút rơi vào đường dẫn đó bao nhiêu lần, Conrad nằm ở giữa nhiều đường đi ngắn nhất giữa các tác nhân hơn bất kỳ ai khác.
# >
# > - Đây là những cách khác nhau để nhìn vào trung tâm.
# >
# > 4. **Eigenvector centrality** được sử dụng trong thuật toán pagerank của Google. Điều nó làm là nói rằng nếu bạn đi bộ ngẫu nhiên qua mạng lưới, không có ràng buộc, bạn chỉ đi bộ ngẫu nhiên, xác suất mà một nút nhất định sẽ xuất hiện trên đoạn đường đi ngẫu nhiên đó là bao nhiêu?
#
# Điều xảy ra khi bạn có cấu trúc là khả năng bạn sẽ đi từ một nhóm này sang nhóm khác là khá thấp so với khả năng bạn sẽ ở trong một nhóm duy nhất. Trong một mạng lưới như thế này, vì nhóm ở góc trên bên phải có một chút lớn hơn, nên khả năng một nút chỉ lưu thông trong nhóm đó ở góc trên bên phải là cao hơn, và đó là lý do bạn sẽ thấy một tác nhân trung tâm đặc biệt trong nhóm đó sẽ nổi bật. Chúng ta thấy rằng các **eigenvectors** cao nhất có xu hướng có sự tương quan cao với **degree** cao nhất trong nhóm đó ở góc trên. Nhưng nó được sử dụng để có một cảm giác nếu chúng ta thực hiện các chuyển động ngẫu nhiên qua mạng lưới, một người sẽ có tần suất như thế nào hoặc mức độ trung tâm hay ảnh hưởng ra sao?
#
# Trên đây là bốn phép đo trung tâm cơ bản, và chúng ta sẽ học cách tính toán **degree centrality** trong bài học này.

# %% [markdown]
# ### **Network Measures of Centrality**
#
# >**Degree** là số lượng cạnh kết nối với một nút.
#
# >**Betweenness** là mức độ mà nó nằm trên đường đi ngắn nhất giữa các nút.
#
# >**Closeness** là trung bình khoảng cách ngắn nhất đến tất cả các nút khác trong mạng lưới, và
#
# >**Eigenvector** đo lường mức độ mà một nút kết nối với những nút có ảnh hưởng khác.
#
# Không phải là ai đang kết nối với bạn mà là bạn đang kết nối với ai hoặc bạn có kết nối với những người có ảnh hưởng không? Những phép đo này cho tôi biết gì?
#
# ### **What do the Measures Tell Me?**
#
# Nó hơi khác một chút. **Degree** là mức độ tiếp xúc với mạng lưới.
# - Khi bạn nghĩ đến việc phát tán một tin tức gây sốc hay một cái gì đó như vậy, nút có nhiều kết nối sẽ nhận thông tin ban đầu và phát tán ra mạng lưới đến nhiều người nhất.
# - Tuy nhiên, chúng ta thấy rằng những người có **degree** cao không có nhiều sức ảnh hưởng. Họ không thay đổi được suy nghĩ, không nắm quyền lực thực sự để động viên hoặc thuyết phục, nhưng đó là cách để đưa thông tin ra ngoài. Ngay cả khi khả năng thuyết phục của bạn thấp, bạn bắt đầu với nhiều người hơn.
# - Đó là điều **degree** cho bạn biết là tiếp xúc với mạng lưới.
#
# **Betweenness**, đây là ý tưởng về quyền lực không chính thức.
# - Đây là ý tưởng về việc trung gian hóa kiến thức và nguồn lực trong toàn tổ chức.
# - Các bạn đã từng ở trong những tổ chức mà có có người không chịu trách nhiệm chính, nhưng họ biết chỗ nào có mẫu đơn, họ biết cách giải quyết công việc. Họ tham gia vào công việc và biết cách giải quyết vấn đề. Những người đó xây dựng quyền lực không chính thức, và họ có rất nhiều kết nối ở những nơi khác.
# - Sự trung gian không chính thức, việc canh giữ giữa một trung tâm như Conrad có khả năng trung gian hóa kiến thức từ nhóm ở phía bên phải sang nhóm ở phía bên trái dưới cùng. Đôi khi, đó có thể là một vị trí quyền lực lớn. Những lúc khác nó có thể khiến bạn kiệt sức về mặt nhận thức, khi bạn là người đi tới giữa hai nhóm.
# - Trong trường hợp của Conrad, anh ấy cuối cùng đã nghỉ việc, và tổ chức tan rã vì điều đó, và tướng quân về hưu, đó không phải là một câu chuyện thành công. Nhưng đó là **betweenness**.
#
# **Closeness** thường được sử dụng để truyền bá thông tin vì nó giúp thông tin được tiếp cận nhanh chóng.
# - Giống như khi tin đồn đang lan truyền qua mạng lưới hoặc bạn muốn bắt đầu một tin đồn lan truyền qua mạng lưới.
# - Nếu bạn có thể tìm ra điểm hoặc người có **closeness** cao, đó là điểm lan truyền thông tin nhanh chóng.
#
# Cuối cùng, như đã đề cập về **eigenvector**, nó giúp bạn kết nối với những nút có degree cao.
# - Đôi khi, khi bạn có thể tìm ra một nút có **eigenvector centrality** cao, nhưng degree thấp, bạn đang tìm thấy một nút tuyệt vời để phát tán tin đồn hoặc thông tin sai lệch mà không nhất thiết sẽ bị phát hiện, vì hầu hết các thuật toán mà mọi người sử dụng đều tìm các nút có degree cao vì đó là phép đo dễ tính toán nhất.
#
# Nếu bạn có thể tìm thấy một nút có degree thấp nhưng có một trong các giá trị khác cao, đó sẽ là một mục tiêu thú vị và nếu bạn muốn giỏi hơn trong việc phát hiện thông tin sai lệch, bạn cần phải tìm những cách thông minh hơn để phát hiện những nút có thể bắt đầu lan truyền tin đồn mà không nhất thiết bị phát hiện.

# %% [markdown]
# ### **Degree centrality**
# Degree đơn giản là số lượng các cạnh kết nối với một nút.
#
# ![Hình 8](fig8.png)
#
# Nếu tôi nhìn vào mạng lưới này ở đây như một ví dụ,
#
# Bước đầu tiên tôi sẽ làm là ghi lại phương trình ở đây,
# $$ C_{D_i} = \frac{\sum_{j=1}^{n} a_{ij}}{n - 1} $$
#
# Đây là **degree centrality** cho một nút nhất định
# - I cho trước sẽ là tổng các phần tử của hàng trong ma trận kề, và chúng ta sẽ chia cho $n-1$. Điều này trông như thế nào?
#
# Hãy để tôi tạo một ma trận kề.
#
# ![Hình 9](fig9.png)
#
# Một điều nữa về ma trận kề là đường chéo của ma trận kề là không xác định.
# > Điều này có nghĩa là gì khi một tác nhân kết nối với chính nó? Điều này có nghĩa là gì khi một tác nhân là bạn của chính nó? Trong một lập luận, bạn có thể nói, tôi thực sự biết tôi là ai. Một lập luận khác là, tôi không phải như vậy, tôi có đang dành thời gian vô hạn với chính mình không? Đó là một khái niệm kỳ lạ.
#
# Trong phân tích mạng xã hội, chúng ta chỉ coi đường chéo chủ yếu là không xác định.
# > Nếu tôi nhìn vào một tác nhân, tôi có thể thấy ở đây Tác nhân 1 chỉ kết nối với Tác nhân 4, không phải với các tác nhân khác. Tôi có thể làm điều tương tự cho Tác nhân 2. Điều tương tự với Tác nhân 3, Tác nhân 4 kết nối với ba tác nhân khác nhau, và sau đó là Tác nhân 5. Đó là ma trận kề.
#
# Từ ma trận kề, tôi có thể đơn giản chỉ cần cộng lại các giá trị trong hàng và tôi có thể có giá trị ở đó, sau đó tôi sẽ chia cho $n-1$.
# > Có bao nhiêu liên kết khả thi nếu một nút kết nối với tất cả mọi người? Có năm tác nhân trong mạng lưới này.
#
# Nếu một nút kết nối với tất cả các tác nhân còn lại, số lượng tối đa mà nó có thể kết nối là bốn nút khác, vì nó sẽ không kết nối với chính nó. Do đó, $n-1$ là bốn, và điều đó cho tôi một **degree** là 1/4, 1/4, 2/4, 3/4 và 1/4. Điều đó trở thành **degree** của mỗi nút trong mạng lưới.
#
# ![Hình 10](fig10.png)
#
# Tôi cũng có thể thay đổi kích thước của các nút theo degree tương đối của chúng, và điều đó cung cấp cho bạn một cái nhìn trực quan hơn về ai là các tác nhân trung tâm nhất trong mạng lưới.
#
# ![Hình 11](fig11.png)
#
# ### **Degree centrality Practical ExcerciseExcercise**
# Đây là một ví dụ về một mạng lưới khác cho bạn.
#
# ![Hình 12](fig12.png)
#
# Những gì tôi muốn bạn làm là tạm dừng, và tự mình tính toán **degree centrality** cho chính bạn.
#
# Nếu bạn không thể làm bài toán một cách độc lập mà không có sự trợ giúp, bạn chưa thành thạo nó, bạn chưa học được nó.
#
# <details>
#   <summary>Đáp án </summary>
#
#   ![Hình 13](fig13.png)
#
#   Điều đầu tiên chúng ta sẽ làm là tạo ma trận kề khi chúng ta cộng lại các giá trị trong các hàng. Bạn sẽ có các giá trị mà bạn thấy ở đây. Chúng ta lại chia cho 4 vì có năm tác nhân trong mạng lưới, và bạn sẽ thấy các **degree centrality** khác nhau.
#
#   Đây là mạng lưới được thay đổi kích thước theo degree centrality.
#
#   ![Hình 14](fig14.png)
#
# </details>

# %% [markdown]
# ## Betweenness Centrality

# %% [markdown]
# Quay lại với ví dụ mạng mà chúng ta đã thấy
#
# ![Hình 7](fig7.png)
#
# **Betweenness centrality** được chỉ ra bởi **Conrad**. Và vì vậy, **Betweenness centrality** không nhất thiết phải là một người trung gian duy nhất. **Conrad** là đặc biệt ở chỗ anh ấy là một nút có **betweenness** cao và cũng có **degree** thấp, so với một số thành viên khác trong mạng lưới. Điều bạn thường thấy là khi mạng lưới giống như một khối, đúng không? Nó thường có sự phân bố **degree** khá đối xứng, đúng không? Mọi người gần như đều giống nhau hoặc là một khối duy nhất trong mạng lưới.
#
# Nếu chúng ta chỉ lấy nhóm trên hoặc nhóm dưới này, bạn sẽ thấy rằng **degree**, **betweenness**, **closeness**, và **eigenvector** đều có sự tương quan cao với nhau. Và vì vậy, một người có ảnh hưởng sẽ có ảnh hưởng trong tất cả các khía cạnh của phép đo đó. Nhưng khi mạng lưới bắt đầu có cấu trúc, như ở đây, nơi bạn thấy hai nhóm, đúng không? Đó là khi có sự khác biệt trong các phép đo này.
#
# **Betweenness** là một phép đo về sự trung gian, là một phép đo về việc trung gian hóa kiến thức và sự phân bố nguồn lực trong tổ chức. Vì vậy, nếu có kiến thức trong nhóm ở góc trên bên phải, thì đây là hai nhóm đã hợp nhất lại và đó là điều quan trọng đối với những người trong nhóm bên trái dưới cùng. Nếu nó không rõ ràng và sẵn có ngay lập tức, nếu có sự hợp tác hay phối hợp nào đó. **Conrad** là người có mối quan hệ và được tôn trọng từ cả hai nhóm, và phần lớn những điều đó sẽ thông qua qua anh ấy.
#
# Chúng ta cũng có một khái niệm mà chúng ta sẽ nói đến sau trong khóa học này gọi là **Network Horizon** (horizon mạng). Đó là sự nhận thức của mọi người về kiến thức và thông tin mà những người trong mạng lưới của họ sở hữu, thực chất là giảm dần đến không ở ba bước trong mạng lưới. Vì vậy, bạn biết những người bạn tương tác với họ thường xuyên. Bạn có thể biết điểm mạnh và điểm yếu của họ, kỹ năng của họ, họ biết gì, họ có thể cung cấp gì.
#
# Bạn có thể có một ý tưởng nếu bạn đi một bước xa hơn, nhưng ngoài điều đó, nó sẽ bị phá vỡ. Và khi tổ chức bắt đầu trở nên lớn, và trở nên không thực tế để mọi người biết tất cả mọi người, đúng không? Đó là khi cấu trúc tổ chức bắt đầu có vai trò, vì đó là điều giúp chúng ta nhận diện và tìm kiếm thông tin, kiến thức và tài nguyên trong tổ chức. Nhưng nếu không có điều đó, sẽ có những tác nhân thay vì chiếm vị trí trung tâm trong một nhóm nhỏ hoặc cụm, họ sẽ nối giữa chúng. Và đó là trường hợp ở đây của **Conrad** với **betweenness**.
#
# Bây giờ, chúng ta sẽ thấy rằng một số tác nhân thực sự cố gắng chiếm các vị trí như **Conrad** như một chiến lược. Họ không muốn **Joe** gặp **Pete**, đúng không? Họ không muốn **Bob** gặp **Pat**, đúng không? Bởi vì nếu thế, điều đó sẽ đe dọa quyền lực và địa vị của họ trong tổ chức. Và khi bạn thấy điều đó, nó không thể mở rộng được. Và cuối cùng tạo ra những cấu trúc độc hại mà cuối cùng làm tổn hại tổ chức, hoặc ít nhất là giới hạn sự phát triển của nó.
#
# Có những loại tác nhân khác trong vị trí này luôn gặp gỡ những người mới. Vì vậy, họ rất vui khi chuyển giao mối quan hệ này giữa **Bob** và **Will** và **Roger** và **Pete**. Và để họ tự quản lý mối quan hệ trung gian của mình. Và họ sẽ đi tìm những người mới và tìm thấy một cụm mới không được mô tả ở đây và mang những tài nguyên đó vào. Vì vậy, khi bạn có một người luôn mở rộng mối quan hệ, luôn gặp gỡ những tác nhân mới, đó là nơi bạn sẽ có một văn hóa tăng trưởng kiến thức, tăng trưởng tài nguyên, thường là tăng trưởng từ cấu trúc đó.
#
# Bạn cũng có một mặt tối của **betweenness**, khi **Conrad** có trách nhiệm này, nó có thể trở nên quá tải. Anh ấy không thể hoàn thành công việc của mình vì anh ấy đang bận quản lý các yêu cầu đi qua lại giữa hai nhóm. Và **brokerage** có lẽ không phải là chỉ số hiệu suất chủ chốt trong mô tả công việc của anh ấy. Vì vậy, anh ấy có một công việc chính để làm, ngoài ra anh ấy còn là người trung gian cho tất cả các giao tiếp giữa hai cụm này. Điều đó có thể là quá tải, yêu cầu nhận thức cao, tốn thời gian và là một sự "tiêu tốn" thời gian đối với anh ấy. Và vì vậy, đó có thể là một vị trí không đáng mơ ước, đúng không?
#
# Tùy thuộc vào cách các tổ chức thưởng cho những yếu tố này, tùy thuộc vào việc liệu chúng ta có ai đó cố gắng làm người kiểm soát hay một người trung gian thực sự, và giới thiệu người khác như một kết nối, tất cả những điều đó có thể được đo lường qua **betweenness**. Đây sẽ là phép đo tương tự mà chúng ta sẽ nói đến trong bài giảng này, nhưng ý nghĩa của nó đối với tổ chức có thể khác.

# %% [markdown]
# ![Hình 15](fig15.png)

# %% [markdown]
# Điều chúng ta muốn biết là mức độ mà một nút nằm trên đường đi ngắn nhất giữa các nút khác. Vậy làm thế nào chúng ta sẽ làm điều đó?
#
# Điều đầu tiên mà chúng ta phải làm là qua ký hiệu $nC_k$. Chúng ta phải biết có bao nhiêu đường đi khả thi.
#
# ![Hình 16](fig16.png)
#
# Giống như khi chúng ta làm **degree**, mẫu số là có bao nhiêu nút mà bạn có thể kết nối, đó là $n-1$. Vậy khi chúng ta muốn biết có bao nhiêu đường đi khả thi thì chúng ta cần phải nói có hai nút, đó là $nC_2$ sẽ là các đường đi. Vì vậy, có $n$ nút, và tôi sẽ nói có bao nhiêu cặp, đó là ký hiệu $nC_2$.
#
# > Điều này cho ra kết quả là 10 đường đi khả thi cho mạng lưới này. Vì vậy, đối với 5 tác nhân, hãy liệt kê chúng.
#
# Bước tiếp theo mà chúng ta sẽ làm là tính toán các **geodesics** và đây là bước khó khăn nhất mà chúng ta có thể làm. Đôi khi có nhiều hơn một **geodesic** giữa hai nút.
#
# ### **Geodesic là gì?**
#
# - **Geodesic** là đường đi dài nhất và ngắn nhất. Vì vậy, chúng ta sẽ nhìn vào đường đi ngắn nhất giữa các cặp và chúng ta sẽ xem những gì đó là gì? Đó là **geodesic**.
#
#   > Trong trường hợp từ 1 đến 2, đó đơn giản chỉ là từ 1 đến 2, còn từ 1 đến 3 thì cũng có một kết nối trực tiếp từ 1 đến 3. Nó trở nên thú vị khi chúng ta nhìn vào việc đi từ Tác nhân 1 đến Tác nhân 4. Vì đường ngắn nhất để đến đó là từ 1 đến 3 đến 4, đúng không? Nếu tôi đi 1 đến 2 đến 3 đến 4, đó là một đường đi, nhưng đó không phải là một đường đi **geodesic**. Đó không phải là một đường đi ngắn nhất. Chúng ta phải đi từ 1 đến 3 đến 4, nút thứ 2 là thừa.
#
# ![Hình 17](fig17.png)

# %% [markdown]
# Trong mạng lưới này, mỗi cặp nút thường chỉ có một **geodesic** (đường đi ngắn nhất). Tuy nhiên, trong một số trường hợp, có thể tồn tại nhiều hơn một **geodesic** giữa hai nút.
#
# > Giả sử có một nút 6 nằm bên trái của Tác nhân 1 và 2. Khi đó, để đi từ nút 3 đến nút 6, có hai lựa chọn:
# > - Đi theo đường 3 → 2 → 6.
# > - Đi theo đường 3 → 1 → 6.
#
# Như vậy, có hai **geodesics** giữa 3 và 6. Điều này cho thấy rằng một số đường đi có thể có nhiều hơn một **geodesic**.
#
# Bây giờ, chúng ta sẽ tính tỷ lệ phần trăm số **geodesics** mà một nút nằm ở vị trí trung gian.
#
#
# ![Hình 18](fig18.png)
#
# Khi một đường đi chỉ có một bước (độ dài bằng 1), không có nút nào nằm giữa. Chúng ta không xét các điểm đầu và điểm cuối, mà chỉ quan tâm đến các nút trung gian. Do đó, trong các đường đi ngắn nhất như vậy, giá trị trung gian của tất cả các nút sẽ là 0.
#
# Tuy nhiên, khi xét các đường đi dài hơn, một số nút có thể nằm giữa. Ví dụ, trong một mạng lưới, nếu nút 3 nằm ở giữa tất cả các **geodesics**, thì nó sẽ có giá trị trung gian là 1.
#
# Giả sử chúng ta có hai đường đi từ 1 đến 4:
# - **1 → 3 → 6 → 4**
# - **1 → 3 → 7 → 4**
#
# Trong trường hợp này, nút 3 nằm trên cả hai **geodesics**, nên giá trị trung gian của nó vẫn là 1. Nhưng các nút 6 và 7 chỉ nằm trên một trong hai đường đi, nên chúng có giá trị trung gian là 0.5.
#
# Tiếp theo, chúng ta sẽ tính tổng số **geodesics** mà một nút nằm ở giữa. Chúng ta thấy rằng nút 3 nằm trên 5 **geodesics**, trong tổng số các **geodesics** có thể có. Khi đó, tử số của phép tính sẽ là **0, 0, 5, 0, 0**, như đã xác định.
#
# ![Hình 19](fig19.png)
#
# Mẫu số cần được điều chỉnh bằng cách loại bỏ nút đang xét, vì nó không thể là điểm bắt đầu hoặc điểm kết thúc của đường đi. Nếu ttôi lấy bất kỳ nút nào ra, tôi có thể lấy Tác nhân 5 ra khỏi phương trình, chỉ còn lại 4 nút. Số đường đi giữa 4 nút này được tính theo công thức tổ hợp:
# $$4C_2 = \frac{4 \times 3}{2} = 6.$$
#
# Một cách khác để nhìn nhận vấn đề là thay vì sử dụng công thức $n \times (n-1)$, ta thay thế $n$ bằng $n-1$. Do đó, thay vì tính với 5 nút, ta xét khả năng Tác nhân 5 nằm trên đường đi giữa các nút còn lại, dẫn đến:
# $$4 \times 3 = 12,$$
# nhưng vì mỗi đường đi được đếm hai lần, kết quả cuối cùng vẫn là 6 đường đi ngắn nhất.

# %% [markdown]
# Với mẫu số này, chúng ta có thể tính toán điểm số betweenness, như bạn thấy trong hình trên. Tại sao lại cần thực hiện điều này với mẫu số? Mục tiêu của chúng ta là chuẩn hóa tất cả các phép đo centrality trong khoảng từ 0 đến 1. Điều này giúp việc so sánh các giá trị trở nên dễ dàng hơn.
#
# Khi xem xét mức độ centrality tương đối của các tác nhân khác nhau, một số phần mềm ứng dụng chuẩn hóa dữ liệu theo thang đo từ 0 đến 100, trong khi một số khác sử dụng giá trị thô. Tuy nhiên, việc dùng con số thô có thể gây khó khăn khi so sánh giữa các mạng lưới có kích thước khác nhau. Do đó, để phù hợp với khóa học này, chúng ta sẽ sử dụng chuẩn hóa trong phạm vi từ 0 đến 1, giúp điều chỉnh kích thước các nút theo centrality tương đối của chúng một cách dễ dàng hơn.

# %% [markdown]
# ![Hình 20](fig20.png)
#
# Như trong bài giảng trước, tôi muốn bạn dành một chút thời gian để thực hành. Hãy tạm dừng video, sử dụng mạng lưới này và thử tính toán các bước bằng tay theo những gì tôi vừa hướng dẫn. Tôi không khuyến khích bạn tiếp tục bài giảng và chỉ quan sát tôi giải quyết vấn đề thêm một lần nữa mà chưa tự mình thực hiện. Nếu chưa làm bài tập một cách độc lập, bạn sẽ chưa thực sự nắm vững nội dung này. Vì vậy, hãy thử giải quyết trước khi tiếp tục theo dõi bài giảng.
#
# Giả sử bạn đã tạm dừng và giành thời gian thực hành.
#
# Bây giờ chúng ta sẽ cùng đi qua phần giải pháp.
#
# ![Hình 21](fig21.png)
#
# Trước tiên, chúng ta sẽ liệt kê các **geodesics** các nút: từ 1 đến 2, từ 1 đến 3, từ 1 đến 4, v.v. Sau đó, chúng ta sẽ xem xét tất cả các đường đi giữa các cặp nút.
#
# Ví dụ, từ 1 đến 2 là đường đi trực tiếp, tương tự như từ 1 đến 3. Tuy nhiên, để đi từ 1 đến 4, ta phải đi qua Tác nhân 5. Tương tự, từ 1 đến 6 cũng phải đi qua Tác nhân 5.
#
# Một trường hợp thú vị là đường đi từ 2 đến 3. Có hai lựa chọn: đi theo đường 2 → 1 → 3 hoặc 2 → 5 → 3. Đây là điểm mà nhiều người thường mắc lỗi, vì họ chỉ xác định một đường đi duy nhất giữa hai nút mà không nhận ra rằng có nhiều lựa chọn. Việc chú ý đến tất cả các đường đi là điều quan trọng khi tính toán betweenness centrality.
#
# ![Hình 22](fig22.png)
#
# Tiếp theo, chúng ta sẽ xem xét tần suất mỗi nút xuất hiện trong các đường đi ngắn nhất. Tác nhân 5 xuất hiện trong hầu hết các **geodesics**. Lưu ý ở Path 2 - 3, Tác nhân 5 chỉ nẳm ở một nửa **geodesics**, và tác nhân 1 xuất hiện trong nửa còn lại.
#
# ![Hình 23](fig23.png)
#
# Khi tổng hợp tất cả các giá trị này, ta có tổng cộng là 0.5 và 7.5, với mẫu số là 10.
#
# Từ đó, chúng ta tính được điểm số betweenness, và có thể thấy mạng lưới đã được thay đổi kích thước tương ứng với giá trị betweenness centrality của từng nút.
